# %%
import pandas as pd
import numpy as np

# %%
# needed to merge together driving and transit estimates manually
zip_estimates = pd.read_csv('data-outputs/zip_summary_driving.csv')

# %%
surveys = pd.read_excel('panynj/all_years.xlsx',sheetname='data')

# %%
surveys.columns
# Out:
# Index(['Year', 'WEIGHT', 'Language', 'TOTAL', 'AIRPORT', 'TERMINAL',
#        'CONCOURSE', 'GATE', 'FLIGHTTYPE', 'AirportNovice', 'TerminalNovice',
#        'AIRLINE', 'DESTINATION', 'DestinationCountry', 'CheckinLocation',
#        'PartySize', 'KidsInParty', 'NumKids', 'GENDER', 'Age', 'AgeGROUPS',
#        'HHIncome', 'ODTravelTimeToAirport', 'AirportDwellTimeDepartOD',
#        'PostSecChkDwellTimeOD', 'BagsCheckedSinglePass',
#        'BagsChecked2PlusPass', 'NumBagsChecked', 'CheckedBagIncidence',
#        'TripPurpose', 'TripOriginOD', 'TripOriginLocationOD', 'TOManhattan',
#        'TONYC', 'TONY', 'TONJ', 'TOCT', 'TOPA', 'TOOtherUS', 'TOZip',
#        'TOTownCity', 'VisitorVsResident', 'NightsVisited', 'NightsAway',
#        'ResidentialRegion', 'PrimaryResidentialLocation', 'MAINMODE',
#        'SunnyWeather', 'DryWeather', 'WetWeather', 'DryOrWet', 'ZipProvided'],
#       dtype='object')

# %%
# surveys.groupby(['ZipProvided','TripOriginLocationOD']).size()

# %%
surveys.TOZip[surveys.TOZip!=' '].shape
# surveys.TOZip[surveys.ZipProvided==1].shape
# Out:
# (11447,)

# %%
# label each value of MAINMODE with a category
modes_reported = {'A':'train',
'E':'train',
'J':'train',
'Z':'train',
'LIRR Connecting to JFK AirTrain':'train',
'Other (NYC Subway, including Connection to JFK AirTrain)':'train',
'Airlink New York':'van',
'All County Express':'van',
'Connecticut Limousine':'van',
"Dave's Best Limousine":'van',
'ETS Airport Shuttle':'van',
'Other (Shared-Ride Van/Service)':'van',
'Prime Time Shuttle of Connecticut':'van',
'State Shuttle':'van',
'SuperShuttle from Long Island':'van',
'SuperShuttle from Manhattan':'van',
'Limo/Executive Car/Town Car Service':'limo',
'Chartered/Tour Bus':'bus',
'NYC Airporter Bus from JFK/LaGuardia Airports':'bus',
'NYC Airporter Bus from Manhattan':'bus',
'Public/City Bus (that is, a local bus)':'bus',
'Transbridge Bus':'bus',
'Taxi':'taxi',
'Air Park':'local_van',
'Dollar Airport Parking':'local_van',
'Hilton Hotel':'local_van',
'Holiday Inn FSP':'local_van', 
'Hotel/Motel Shuttle/Van':'local_van',
'JFK Marriott Hotel':'local_van',
'National Airport Parking':'local_van',
'Other (Off-Airport Parking Shuttle/Van)':'local_van',
'Park Plus':'local_van',
'Sky Park/Central Parking':'local_van',
'The Parking Spot JFK/LGA':'local_van',
'U-Save':'local_van',
'Vista Airport Parking':'local_van',
'Drove Your Own Car':'private',
'Passenger in Car Parked at Airport':'private',
'Passenger in Car and Dropped Off at Airport':'private',
'Avis':'rental',
'Budget':'rental',
'Dollar':'rental',
'Enterprise':'rental',
'Hertz':'rental',
'National':'rental',
'Other (Drove Rental Car)':'rental'}

# %%
# label each value of MAINMODE with a category
modes_model = {'A':'transit',
'E':'transit',
'J':'transit',
'Z':'transit',
'LIRR Connecting to JFK AirTrain':'transit',
'Other (NYC Subway, including Connection to JFK AirTrain)':'transit',
'Airlink New York':'other',
'All County Express':'other',
'Connecticut Limousine':'other',
"Dave's Best Limousine":'other',
'ETS Airport Shuttle':'other',
'Other (Shared-Ride Van/Service)':'other',
'Prime Time Shuttle of Connecticut':'other',
'State Shuttle':'other',
'SuperShuttle from Long Island':'other',
'SuperShuttle from Manhattan':'other',
'Limo/Executive Car/Town Car Service':'taxi-FHV',
'Chartered/Tour Bus':'other',
'NYC Airporter Bus from JFK/LaGuardia Airports':'other',
'NYC Airporter Bus from Manhattan':'other',
'Public/City Bus (that is, a local bus)':'transit',
'Transbridge Bus':'other',
'Taxi':'taxi-FHV',
'Air Park':'other',
'Dollar Airport Parking':'other',
'Hilton Hotel':'other_free',
'Holiday Inn FSP':'other_free', 
'Hotel/Motel Shuttle/Van':'other_free',
'JFK Marriott Hotel':'other_free',
'National Airport Parking':'other',
'Other (Off-Airport Parking Shuttle/Van)':'other',
'Park Plus':'other',
'Sky Park/Central Parking':'other',
'The Parking Spot JFK/LGA':'other',
'U-Save':'other',
'Vista Airport Parking':'other',
'Drove Your Own Car':'other',
'Passenger in Car Parked at Airport':'other',
'Passenger in Car and Dropped Off at Airport':'other_free',
'Avis':'other',
'Budget':'other',
'Dollar':'other',
'Enterprise':'other',
'Hertz':'other',
'National':'other',
'Other (Drove Rental Car)':'other',
'Alamo':'other',
'AviStar/AviStar Haynes':'other',
'Corporate':'taxi-FHV',
"Don't know":'other',
'Four Points Sheraton Hotel Parking':'other',
'JFK AirTrain':'transit',
'JFK Crowne Plaza':'other_free',
'Metro-North Railroad':'transit',
'Metro-North Railroad Hudson Line Connecting to a Bus/Taxi':'transit',
"Mr. B's Park & Lock":'other',
"NJ Transit or Amtrak Connecting to Newark Liberty Airport AirTrain":'transit',
"NJ Transit or Amtrak Connecting to Shuttle Bus to Newark Liberty Airport":'transit',
"NY Airport Service Bus from Manhattan":'other',
"NY Airport Service Bus to JFK/LaGuardia Airports":'other',
"NYC Airporter Bus to JFK/LaGuardia Airports":'other',
"Newark Liberty Airport Express Bus from Manhattan":'other',
'None/Nothing/NA':'other',
"Olympia Trails":'other',
'On-Airport Terminal Access Shuttle Bus':'other_free',
'Other':'other',
'Other (Please Specify)':'other',
'Other Specify':'other',
'Payless':'other',
'Refused':'other',
'Smart Park':'other',
'SuperShuttle':'other',
'SuperShuttle to Long Island':'other',
'SuperShuttle to Manhattan':'other',
'SuperShuttle to Manhattan/Long Island':'other',
'The Parking Spot Haynes':'other',
'Visconti Ground Transportation':'other',
'Westchester Express':'other'}

# %%
# check that all possible MAINMODE values are assigned a grouping
mode_compare = pd.DataFrame(surveys.groupby('MAINMODE').size(),columns=['count'])
mode_compare['2014_reported_mode'] = pd.Series(modes_reported)
mode_compare['MNL_model_mode'] = pd.Series(modes_model)
mode_codes = {'taxi-FHV':1,'transit':2,'other':3,'other_free':4}
mode_compare = mode_compare.merge(pd.DataFrame.from_dict(mode_codes,orient='index').rename(columns={0:'CHOICE'}),left_on='MNL_model_mode',right_index=True)
mode_compare
# Out:
#                                                     count 2014_reported_mode  \
# MAINMODE
# A                                                     359              train
# E                                                     419              train
# J                                                      34              train
# JFK AirTrain                                            1                NaN
# LIRR Connecting to JFK AirTrain                       509              train
# Metro-North Railroad                                    1                NaN
# Metro-North Railroad Hudson Line Connecting to ...      2                NaN
# NJ Transit or Amtrak Connecting to Newark Liber...    506                NaN
# NJ Transit or Amtrak Connecting to Shuttle Bus ...     78                NaN
# Other (NYC Subway, including Connection to JFK ...     10              train
# Public/City Bus (that is, a local bus)                561                bus
# Z                                                       4              train
# Air Park                                               31          local_van
# Airlink New York                                      172                van
# Alamo                                                   6                NaN
# All County Express                                     11                van
# AviStar/AviStar Haynes                                 10                NaN
# Avis                                                  251             rental
# Budget                                                148             rental
# Chartered/Tour Bus                                    170                bus
# Connecticut Limousine                                  30                van
# Dave's Best Limousine                                  17                van
# Dollar                                                 89             rental
# Dollar Airport Parking                                 12          local_van
# Don't know                                              3                NaN
# Drove Your Own Car                                   1764            private
# ETS Airport Shuttle                                    46                van
# Enterprise                                            190             rental
# Four Points Sheraton Hotel Parking                      3                NaN
# Hertz                                                 321             rental
# ...                                                   ...                ...
# Passenger in Car Parked at Airport                    433            private
# Payless                                                 6                NaN
# Prime Time Shuttle of Connecticut                      12                van
# Refused                                                 1                NaN
# Sky Park/Central Parking                                5          local_van
# Smart Park                                              2                NaN
# State Shuttle                                          70                van
# SuperShuttle                                           73                NaN
# SuperShuttle from Long Island                          16                van
# SuperShuttle from Manhattan                           178                van
# SuperShuttle to Long Island                             2                NaN
# SuperShuttle to Manhattan                              85                NaN
# SuperShuttle to Manhattan/Long Island                  94                NaN
# The Parking Spot Haynes                                 2                NaN
# The Parking Spot JFK/LGA                                6          local_van
# Transbridge Bus                                        24                bus
# U-Save                                                  5          local_van
# Visconti Ground Transportation                          1                NaN
# Vista Airport Parking                                  10          local_van
# Westchester Express                                    13                NaN
# Corporate                                              15                NaN
# Limo/Executive Car/Town Car Service                  2736               limo
# Taxi                                                 6691               taxi
# Hilton Hotel                                           53          local_van
# Holiday Inn FSP                                        18          local_van
# Hotel/Motel Shuttle/Van                               440          local_van
# JFK Crowne Plaza                                        8                NaN
# JFK Marriott Hotel                                     10          local_van
# On-Airport Terminal Access Shuttle Bus                  1                NaN
# Passenger in Car and Dropped Off at Airport          7304            private
#
#                                                    MNL_model_mode  CHOICE
# MAINMODE
# A                                                         transit       2
# E                                                         transit       2
# J                                                         transit       2
# JFK AirTrain                                              transit       2
# LIRR Connecting to JFK AirTrain                           transit       2
# Metro-North Railroad                                      transit       2
# Metro-North Railroad Hudson Line Connecting to ...        transit       2
# NJ Transit or Amtrak Connecting to Newark Liber...        transit       2
# NJ Transit or Amtrak Connecting to Shuttle Bus ...        transit       2
# Other (NYC Subway, including Connection to JFK ...        transit       2
# Public/City Bus (that is, a local bus)                    transit       2
# Z                                                         transit       2
# Air Park                                                    other       3
# Airlink New York                                            other       3
# Alamo                                                       other       3
# All County Express                                          other       3
# AviStar/AviStar Haynes                                      other       3
# Avis                                                        other       3
# Budget                                                      other       3
# Chartered/Tour Bus                                          other       3
# Connecticut Limousine                                       other       3
# Dave's Best Limousine                                       other       3
# Dollar                                                      other       3
# Dollar Airport Parking                                      other       3
# Don't know                                                  other       3
# Drove Your Own Car                                          other       3
# ETS Airport Shuttle                                         other       3
# Enterprise                                                  other       3
# Four Points Sheraton Hotel Parking                          other       3
# Hertz                                                       other       3
# ...                                                           ...     ...
# Passenger in Car Parked at Airport                          other       3
# Payless                                                     other       3
# Prime Time Shuttle of Connecticut                           other       3
# Refused                                                     other       3
# Sky Park/Central Parking                                    other       3
# Smart Park                                                  other       3
# State Shuttle                                               other       3
# SuperShuttle                                                other       3
# SuperShuttle from Long Island                               other       3
# SuperShuttle from Manhattan                                 other       3
# SuperShuttle to Long Island                                 other       3
# SuperShuttle to Manhattan                                   other       3
# SuperShuttle to Manhattan/Long Island                       other       3
# The Parking Spot Haynes                                     other       3
# The Parking Spot JFK/LGA                                    other       3
# Transbridge Bus                                             other       3
# U-Save                                                      other       3
# Visconti Ground Transportation                              other       3
# Vista Airport Parking                                       other       3
# Westchester Express                                         other       3
# Corporate                                                taxi-FHV       1
# Limo/Executive Car/Town Car Service                      taxi-FHV       1
# Taxi                                                     taxi-FHV       1
# Hilton Hotel                                           other_free       4
# Holiday Inn FSP                                        other_free       4
# Hotel/Motel Shuttle/Van                                other_free       4
# JFK Crowne Plaza                                       other_free       4
# JFK Marriott Hotel                                     other_free       4
# On-Airport Terminal Access Shuttle Bus                 other_free       4
# Passenger in Car and Dropped Off at Airport            other_free       4
#
# [78 rows x 4 columns]

# %%
surveys.groupby('TripPurpose').size()
# Out:
# TripPurpose
#                                  11
# Both Business/Non-Business     2626
# Business                       5053
# Illness/Bereavement             613
# Leisure/Vacation/Visiting     15233
# Moving/Relocation               386
# Other                           650
# School-Related                 1044
# dtype: int64

# %%
surveys.groupby('HHIncome').size()
# Out:
# HHIncome
# $100,000 - $124,999    1627
# $125,000 - $149,999     987
# $150,000 - $174,999     721
# $175,000 - $199,999     515
# $200,000 - $249,999     571
# $25,000 - $29,999       623
# $250,000 - $299,999     348
# $30,000 - $39,999       860
# $300,000 or More        397
# $300,000 or more        496
# $40,000 - $49,999      1097
# $50,000 - $59,999      1170
# $60,000 - $69,999      1206
# $70,000 - $79,999      1308
# $80,000 - $89,999      1248
# $90,000 - $99,999      1078
# No Answer              9750
# Under $25,000          1614
# dtype: int64

# %%
# extract only useful survey data
df = surveys.query('AIRPORT=="JFK"')
df = df[['TOZip','MAINMODE','FLIGHTTYPE','VisitorVsResident','TripPurpose','HHIncome']]
# convert variables to numeric for model
df['zipcode'] = pd.to_numeric(df['TOZip'],errors='coerce')
df['VisitorVsResident'] = pd.to_numeric(df['VisitorVsResident'],errors='coerce')
df['BusinessPurpose'] = 0
df.loc[:,'BusinessPurpose'][df['TripPurpose']=='Business'] = 1
df.loc[:,'BusinessPurpose'][df['TripPurpose']=='Both Business/Non-Business'] = 1
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df['LowIncome'] = 0
df.loc[:,'LowIncome'][df['HHIncome']=='Under $25,000'] = 1
df.loc[:,'LowIncome'][df['HHIncome']=='$25,000 - $29,999'] = 1
df.loc[:,'LowIncome'][df['HHIncome']=='$30,000 - $39,999'] = 1
df.loc[:,'LowIncome'][df['HHIncome']=='$40,000 - $49,999'] = 1
df.loc[:,'LowIncome'][df['HHIncome']=='$50,000 - $59,999'] = 1
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df.head(25)
# Out:
#     TOZip                                       MAINMODE     FLIGHTTYPE  \
# 13                                                  Taxi       Domestic
# 14                   Limo/Executive Car/Town Car Service       Domestic
# 15           Passenger in Car and Dropped Off at Airport       Domestic
# 16                                                  Taxi       Domestic
# 17  80528                                           Taxi       Domestic
# 18                                                  Taxi       Domestic
# 19                                    Drove Your Own Car       Domestic
# 20                                                  Taxi       Domestic
# 21  10019            Limo/Executive Car/Town Car Service       Domestic
# 22                                                  Taxi       Domestic
# 23                                                  Taxi       Domestic
# 24                   Limo/Executive Car/Town Car Service       Domestic
# 25                       LIRR Connecting to JFK AirTrain       Domestic
# 26                   Limo/Executive Car/Town Car Service       Domestic
# 42                   Limo/Executive Car/Town Car Service       Domestic
# 43                                                  Taxi       Domestic
# 44                   Limo/Executive Car/Town Car Service       Domestic
# 45                       LIRR Connecting to JFK AirTrain       Domestic
# 46           Passenger in Car and Dropped Off at Airport       Domestic
# 47                                                  Taxi  International
# 48  11420             Passenger in Car Parked at Airport       Domestic
# 77                               Hotel/Motel Shuttle/Van  International
# 78  11111                                           Taxi  International
# 79                   Limo/Executive Car/Town Car Service  International
# 80  14624  NYC Airporter Bus from JFK/LaGuardia Airports  International
#
#     VisitorVsResident                 TripPurpose             HHIncome  \
# 13                  1   Leisure/Vacation/Visiting            No Answer
# 14                  1   Leisure/Vacation/Visiting            No Answer
# 15                  1   Leisure/Vacation/Visiting            No Answer
# 16                  1                    Business            No Answer
# 17                  1   Leisure/Vacation/Visiting  $125,000 - $149,999
# 18                  1   Leisure/Vacation/Visiting    $60,000 - $69,999
# 19                  0   Leisure/Vacation/Visiting            No Answer
# 20                  1   Leisure/Vacation/Visiting    $70,000 - $79,999
# 21                  1   Leisure/Vacation/Visiting            No Answer
# 22                  1                    Business  $125,000 - $149,999
# 23                  1   Leisure/Vacation/Visiting        Under $25,000
# 24                  1   Leisure/Vacation/Visiting    $90,000 - $99,999
# 25                  1                    Business            No Answer
# 26                  1                    Business            No Answer
# 42                  1   Leisure/Vacation/Visiting    $60,000 - $69,999
# 43                  1  Both Business/Non-Business            No Answer
# 44                  1   Leisure/Vacation/Visiting    $80,000 - $89,999
# 45                  1   Leisure/Vacation/Visiting  $200,000 - $249,999
# 46                  1   Leisure/Vacation/Visiting    $90,000 - $99,999
# 47                  1   Leisure/Vacation/Visiting            No Answer
# 48                  0   Leisure/Vacation/Visiting    $50,000 - $59,999
# 77                  0         Illness/Bereavement            No Answer
# 78                  0   Leisure/Vacation/Visiting    $30,000 - $39,999
# 79                  1   Leisure/Vacation/Visiting  $150,000 - $174,999
# 80                  0   Leisure/Vacation/Visiting    $30,000 - $39,999
#
#     zipcode  BusinessPurpose  LowIncome
# 13      NaN                0          0
# 14      NaN                0          0
# 15      NaN                0          0
# 16      NaN                1          0
# 17    80528                0          0
# 18      NaN                0          0
# 19      NaN                0          0
# 20      NaN                0          0
# 21    10019                0          0
# 22      NaN                1          0
# 23      NaN                0          1
# 24      NaN                0          0
# 25      NaN                1          0
# 26      NaN                1          0
# 42      NaN                0          0
# 43      NaN                1          0
# 44      NaN                0          0
# 45      NaN                0          0
# 46      NaN                0          0
# 47      NaN                0          0
# 48    11420                0          1
# 77      NaN                0          0
# 78    11111                0          1
# 79      NaN                0          0
# 80    14624                0          1

# %%
df['INTL'] = pd.get_dummies(df['FLIGHTTYPE'])['International']

# %%
df.groupby('VisitorVsResident').size()
# Out:
# VisitorVsResident
# 0    2093
# 1    5991
# dtype: int64

# %%
joined = df.dropna(how='any',subset=['zipcode','VisitorVsResident']).merge(zip_estimates,on='zipcode',how='inner')

# %%
joined = joined.merge(mode_compare,left_on='MAINMODE',right_index=True)

# %%
joined['taxi_mean_duration'] = np.divide(joined['taxi_mean_duration'],60)
joined['transit_duration'] = np.divide(joined['transit_duration'],60)
joined['duration_in_traffic'] = np.divide(joined['duration_in_traffic'],60)
joined['driving_duration'] = np.divide(joined['driving_duration'],60)

# %%
joined.head()
# Out:
#     TOZip                             MAINMODE     FLIGHTTYPE  \
# 0   10019  Limo/Executive Car/Town Car Service       Domestic
# 9   10019  Limo/Executive Car/Town Car Service  International
# 12  10019  Limo/Executive Car/Town Car Service  International
# 18  10019  Limo/Executive Car/Town Car Service       Domestic
# 19  10019  Limo/Executive Car/Town Car Service  International
#
#     VisitorVsResident                TripPurpose             HHIncome  \
# 0                   1  Leisure/Vacation/Visiting            No Answer
# 9                   1  Leisure/Vacation/Visiting            No Answer
# 12                  1  Leisure/Vacation/Visiting     $300,000 or more
# 18                  1  Leisure/Vacation/Visiting  $200,000 - $249,999
# 19                  1  Leisure/Vacation/Visiting        Under $25,000
#
#     zipcode  BusinessPurpose  LowIncome  INTL   ...    taxi_N  \
# 0     10019                0          0     0   ...     33816
# 9     10019                0          0     1   ...     33816
# 12    10019                0          0     1   ...     33816
# 18    10019                0          0     0   ...     33816
# 19    10019                0          1     1   ...     33816
#
#                   route  driving_distance  duration_in_traffic  \
# 0   I-495 E and I-678 S         18.362756            49.866667
# 9   I-495 E and I-678 S         18.362756            49.866667
# 12  I-495 E and I-678 S         18.362756            49.866667
# 18  I-495 E and I-678 S         18.362756            49.866667
# 19  I-495 E and I-678 S         18.362756            49.866667
#
#     driving_duration  transit_duration  count 2014_reported_mode  \
# 0          43.016667         58.083333   2736               limo
# 9          43.016667         58.083333   2736               limo
# 12         43.016667         58.083333   2736               limo
# 18         43.016667         58.083333   2736               limo
# 19         43.016667         58.083333   2736               limo
#
#     MNL_model_mode  CHOICE
# 0         taxi-FHV       1
# 9         taxi-FHV       1
# 12        taxi-FHV       1
# 18        taxi-FHV       1
# 19        taxi-FHV       1
#
# [5 rows x 26 columns]

# %%
biogeme_data = joined.loc[:,['CHOICE','taxi_mean_duration','taxi_mean_total_w_inferred_tip','transit_duration','VisitorVsResident','BusinessPurpose','LowIncome']].reset_index(drop=True)
biogeme_data['TRANSIT_COST'] = 7.75
biogeme_data['FREE_COST'] = 0

# %%
biogeme_data['av1'],biogeme_data['av2'],biogeme_data['av3'] = 1,1,1
biogeme_data['av4'] = 0
biogeme_data.loc[biogeme_data['CHOICE']==4,'av4'] = 1

# %%
biogeme_data['HYPERP'] = (biogeme_data['taxi_mean_total_w_inferred_tip'] - biogeme_data['TRANSIT_COST'])/(biogeme_data['transit_duration']-biogeme_data['taxi_mean_duration'])

# %%
biogeme_data.rename(columns={'taxi_mean_duration':'TAXI_TT','taxi_mean_total_w_inferred_tip':'TAXI_COST','transit_duration':'TRANSIT_TT','VisitorVsResident':'VISITOR','BusinessPurpose':'BUSINESS','LowIncome':'LOWINC'},inplace=True)

# %%
biogeme_data
# Out:
#      CHOICE    TAXI_TT  TAXI_COST  TRANSIT_TT  VISITOR  BUSINESS  LOWINC  \
# 0         1  47.879023  66.695924   58.083333        1         0       0
# 1         1  47.879023  66.695924   58.083333        1         0       0
# 2         1  47.879023  66.695924   58.083333        1         0       0
# 3         1  47.879023  66.695924   58.083333        1         0       0
# 4         1  47.879023  66.695924   58.083333        1         0       1
# 5         1  47.879023  66.695924   58.083333        1         1       0
# 6         1  35.056290  68.523287   72.216667        0         0       0
# 7         1  35.056290  68.523287   72.216667        0         1       0
# 8         1  35.056290  68.523287   72.216667        0         1       0
# 9         1  28.719048  46.052326   64.050000        0         0       0
# 10        1  47.491122  67.825378   60.833333        1         0       0
# 11        1  47.491122  67.825378   60.833333        1         1       0
# 12        1  40.187864  68.178918   62.233333        0         1       0
# 13        1  40.187864  68.178918   62.233333        0         0       0
# 14        1  48.205605  67.065552   74.533333        0         0       0
# 15        1  45.334993  63.905477   72.516667        0         0       0
# 16        1  45.334993  63.905477   72.516667        0         1       1
# 17        1  45.334993  63.905477   72.516667        1         0       0
# 18        1  26.372757  42.945172   65.533333        1         0       0
# 19        1  45.234469  68.219299   75.116667        1         0       0
# 20        1  45.234469  68.219299   75.116667        1         0       0
# 21        1  40.968384  66.608477   53.683333        0         0       0
# 22        1  40.968384  66.608477   53.683333        1         0       0
# 23        1  40.968384  66.608477   53.683333        0         0       0
# 24        1  37.907190  68.396602   66.833333        1         0       0
# 25        1  37.907190  68.396602   66.833333        1         1       0
# 26        1  49.084325  64.829190   71.116667        0         0       0
# 27        1  24.584367  48.903279   58.766667        0         0       0
# 28        1  37.608556  60.258571   55.133333        0         1       0
# 29        1  37.608556  60.258571   55.133333        0         0       0
# ..      ...        ...        ...         ...      ...       ...     ...
# 808       3  42.803860  66.834156   70.383333        0         0       0
# 809       3  14.125000  23.345078   42.400000        0         0       1
# 810       3  46.912685  68.042055   65.050000        1         0       0
# 811       3  39.876030  68.494604   74.750000        0         0       1
# 812       3  39.876030  68.494604   74.750000        0         0       1
# 813       3  39.876030  68.494604   74.750000        0         0       1
# 814       3  39.876030  68.494604   74.750000        0         0       1
# 815       3  38.810000  72.996044   99.766667        0         1       0
# 816       3  29.347586  68.650137   96.000000        1         0       0
# 817       3  42.605425  68.481651   76.600000        0         0       1
# 818       3  35.693011  69.047709   87.883333        1         0       0
# 819       2  46.380616  68.280616   50.016667        1         1       0
# 820       3  46.380616  68.280616   50.016667        1         0       1
# 821       3  38.904598  68.508497   79.633333        1         1       1
# 822       3  33.584752  52.901168   66.500000        0         0       1
# 823       3  23.012366  37.592339   50.533333        0         0       1
# 824       3  39.779015  63.261199   72.583333        1         0       1
# 825       3  22.669048  42.852132   93.116667        1         0       0
# 826       3  38.904598  68.508497   79.633333        1         1       0
# 827       3  39.779015  63.261199   72.583333        1         0       0
# 828       3  17.108497  29.050642   38.316667        1         0       1
# 829       3  32.788889  77.912091   93.583333        1         1       0
# 830       3  36.641667  68.894957   78.700000        0         0       1
# 831       3  25.558333  52.883471   43.866667        0         0       1
# 832       3  40.128275  65.826882   78.900000        1         0       0
# 833       3  42.605425  68.481651   76.600000        1         1       0
# 834       3  26.597222  65.316653   90.983333        1         1       0
# 835       4  12.870833  23.642467   61.183333        1         0       0
# 836       4  22.669048  42.852132   93.116667        1         0       0
# 837       3  19.288889  36.281522   59.116667        1         0       0
#
#      TRANSIT_COST  FREE_COST  av1  av2  av3  av4     HYPERP
# 0            7.75          0    1    1    1    0   5.776571
# 1            7.75          0    1    1    1    0   5.776571
# 2            7.75          0    1    1    1    0   5.776571
# 3            7.75          0    1    1    1    0   5.776571
# 4            7.75          0    1    1    1    0   5.776571
# 5            7.75          0    1    1    1    0   5.776571
# 6            7.75          0    1    1    1    0   1.635432
# 7            7.75          0    1    1    1    0   1.635432
# 8            7.75          0    1    1    1    0   1.635432
# 9            7.75          0    1    1    1    0   1.084101
# 10           7.75          0    1    1    1    0   4.502655
# 11           7.75          0    1    1    1    0   4.502655
# 12           7.75          0    1    1    1    0   2.741104
# 13           7.75          0    1    1    1    0   2.741104
# 14           7.75          0    1    1    1    0   2.252969
# 15           7.75          0    1    1    1    0   2.065932
# 16           7.75          0    1    1    1    0   2.065932
# 17           7.75          0    1    1    1    0   2.065932
# 18           7.75          0    1    1    1    0   0.898740
# 19           7.75          0    1    1    1    0   2.023589
# 20           7.75          0    1    1    1    0   2.023589
# 21           7.75          0    1    1    1    0   4.629077
# 22           7.75          0    1    1    1    0   4.629077
# 23           7.75          0    1    1    1    0   4.629077
# 24           7.75          0    1    1    1    0   2.096602
# 25           7.75          0    1    1    1    0   2.096602
# 26           7.75          0    1    1    1    0   2.590700
# 27           7.75          0    1    1    1    0   1.203935
# 28           7.75          0    1    1    1    0   2.996247
# 29           7.75          0    1    1    1    0   2.996247
# ..            ...        ...  ...  ...  ...  ...        ...
# 808          7.75          0    1    1    1    0   2.142324
# 809          7.75          0    1    1    1    0   0.551550
# 810          7.75          0    1    1    1    0   3.324200
# 811          7.75          0    1    1    1    0   1.741832
# 812          7.75          0    1    1    1    0   1.741832
# 813          7.75          0    1    1    1    0   1.741832
# 814          7.75          0    1    1    1    0   1.741832
# 815          7.75          0    1    1    1    0   1.070368
# 816          7.75          0    1    1    1    0   0.913697
# 817          7.75          0    1    1    1    0   1.786510
# 818          7.75          0    1    1    1    0   1.174503
# 819          7.75          0    1    1    1    0  16.647354
# 820          7.75          0    1    1    1    0  16.647354
# 821          7.75          0    1    1    1    0   1.491785
# 822          7.75          0    1    1    1    0   1.371740
# 823          7.75          0    1    1    1    0   1.084349
# 824          7.75          0    1    1    1    0   1.692192
# 825          7.75          0    1    1    1    0   0.498273
# 826          7.75          0    1    1    1    0   1.491785
# 827          7.75          0    1    1    1    0   1.692192
# 828          7.75          0    1    1    1    0   1.004360
# 829          7.75          0    1    1    1    0   1.154087
# 830          7.75          0    1    1    1    0   1.453813
# 831          7.75          0    1    1    1    0   2.465187
# 832          7.75          0    1    1    1    0   1.497918
# 833          7.75          0    1    1    1    0   1.786510
# 834          7.75          0    1    1    1    0   0.894085
# 835          7.75          0    1    1    1    1   0.328951
# 836          7.75          0    1    1    1    1   0.498273
# 837          7.75          0    1    1    1    0   0.716372
#
# [838 rows x 14 columns]

# %%
biogeme_data['TRANSIT_TT'] = biogeme_data['TRANSIT_TT'].fillna(999.99)
biogeme_data['HYPERP'] = biogeme_data['HYPERP'].fillna(2.62)
biogeme_data.to_csv('models-data/data_26jul_1.dat',sep='\t',index_label='ID')
